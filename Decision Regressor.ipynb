# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import make_regression
from sklearn.metrics import r2_score, root_mean_squared_error
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

# %%
x,y = make_regression(n_features=10, n_samples=300, n_targets=1, n_informative=7)

# %%
x.shape
# Out:
# (300, 10)

# %%
y.shape
# Out:
# (300,)

# %%
data= np.concat([x,y.reshape(300,1)], axis=1)

# %%
df=pd.DataFrame(x, columns=[f"col_{i+1}" for i in range(10)])

# %%
df.head()
# Out:
#       col_1     col_2     col_3     col_4     col_5     col_6     col_7     col_8     col_9    col_10
# 0  0.319021 -0.107684  0.635996 -0.709619 -0.587227 -1.257650 -2.436404 -0.642346  0.641507  0.793471
# 1 -0.798457  0.221788  1.457810 -0.411762  0.534977 -0.778047  0.716118 -1.215296 -0.218611  0.037759
# 2  2.277145 -0.889969 -0.386789  0.049429 -0.484258  1.085482  1.164342  0.367681  0.589931  0.284262
# 3  2.075117  0.555623  1.033184 -0.059778  0.080180 -0.766436 -0.975761 -1.960313  0.538956 -0.091095
# 4 -1.213007  0.009714 -2.314063  1.535187  1.608233  0.294756  1.114663  0.111929 -0.803902  0.707971

# %%
df["target"]= y

# %%
df.head()
# Out:
#       col_1     col_2     col_3     col_4     col_5     col_6     col_7     col_8     col_9    col_10      target
# 0  0.319021 -0.107684  0.635996 -0.709619 -0.587227 -1.257650 -2.436404 -0.642346  0.641507  0.793471  -68.184751
# 1 -0.798457  0.221788  1.457810 -0.411762  0.534977 -0.778047  0.716118 -1.215296 -0.218611  0.037759  101.091997
# 2  2.277145 -0.889969 -0.386789  0.049429 -0.484258  1.085482  1.164342  0.367681  0.589931  0.284262  -40.650424
# 3  2.075117  0.555623  1.033184 -0.059778  0.080180 -0.766436 -0.975761 -1.960313  0.538956 -0.091095   67.948726
# 4 -1.213007  0.009714 -2.314063  1.535187  1.608233  0.294756  1.114663  0.111929 -0.803902  0.707971   72.359381

# %%
plt.figure(figsize=(8,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
x_tr, x_te, y_tr, y_te= train_test_split(x, y, random_state=43, test_size=0.25)

# %%
model= DecisionTreeRegressor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 model= DecisionTreeRegressor()
#
# NameError: name 'DecisionTreeRegressor' is not defined
